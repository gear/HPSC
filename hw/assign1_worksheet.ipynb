# %%
import numpy as np
import assign1 as a

# %%
# %matplotlib inline

# %%
x,y,bem = a.bem(128)

# %%
fem400 = a.get_border(a.fem(32,32,400))

# %%
fem800 = a.get_border(a.fem(32,32,800,False))

# %%
fem2000 = a.get_border(a.fem(32,32,2000,False))

# %%
a.scatter_plot(x,y,bem,fem2000)

# %%
a.scatter_plot(x,y,bem,fem800)

# %%
a.scatter_plot(x,y,bem,fem400)

# %%
fem6000 = a.get_border(a.fem(32,32,6000,False))

# %%
a.scatter_plot(x,y,bem,fem6000)
